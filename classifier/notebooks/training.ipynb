# %%
import sys
sys.path.append("..")
from ArticleDataset import ArticleDataset
from MLPClassifier import MLPClassifier
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch
import torch.nn as nn

# %%
csv_file = "../data/articles.csv"

dataset = ArticleDataset(csv_file, min_freq=5)

# %%
len(dataset)
# Out:
# 1239914

# %%
n = 5
vocab = dataset.vocab
print(len(vocab))
print(f'Title of article {n}: {dataset.data.iloc[n].title.strip()}')
print(f'vocab : {vocab}')
print(f'data for title {n}: {dataset[n]}')
print(f'category of article {n}: {dataset.data.iloc[n].category}')
print(f'index of this category: {dataset.ctoi[dataset.data.iloc[n].category]}')
print("indexes to title:")
for idx in dataset[n][0]:
    print(dataset.itow[idx.item()])

# we can see that everything works fine
# Out:
# 38962
# Title of article 5: Hierarchical quantum embedding by machine learning for large molecular
#   assemblies
# vocab : ['coexistence', 'of', 'distinct', 'mobility', 'edges', 'in', 'a', '1d', 'quasiperiodic', 'mosaic', 'model', 'beyond', 'disorder', 'unveiling', 'multidirectional', 'associative', 'memories', 'on', 'the', 'nature', 'glass', 'transition', 'metallic', 'glasses', 'after', 'deep', 'relaxation', 'relationship', 'between', 'shear', 'moduli', 'and', 'defect', 'induced', 'structural', 'entropy', 'machine', 'learning', 'enhanced', 'calculation', 'quantum', 'classical', 'binding', 'free', 'energies', 'hierarchical', 'embedding', 'by', 'for', 'large', 'molecular', 'assemblies', 'many', 'body', 'localization', 'particle', 'statistics', 'disordered', 'bose', 'hubbard', 'interaction', 'correlated', 'random', 'matrices', 'critical', 'dynamics', 'short', 'range', 'quadratic', 'hamiltonians', 'viscosity', 'polymer', 'melts', 'using', 'non', 'affine', 'theory', 'based', 'vibrational', 'modes', 'les', 'houches', 'lectures', 'theoretical', 'ecology', 'high', 'dimensional', 'models', 'extreme', 'events', 'entanglement', 'states', 'with', 'evolving', 'system', 'conditions', 'when', 'can', 'you', 'get', 'away', 'low', 'memory', 'adam', 'statistical', 'physics', 'analysis', 'graph', 'neural', 'networks', 'approaching', 'optimality', 'contextual', 'stochastic', 'block', 'mechanics', 'semantic', 'compression', 'accuracy', 'capacity', 'modern', 'hopfield', 'synaptic', 'noise', 'dynamical', 'decoupling', 'generalization', 'overfitting', 'two', 'layer', 'bulk', 'edge', 'correspondence', 'at', 'spin', 'to', 'integer', 'hall', 'effect', 'crossover', 'topological', 'superconductors', 'exponents', 'field', 'zero', 'temperature', 'cortical', 'neuronal', 'visual', 'informatics', 'variational', 'transformer', 'ansatz', 'density', 'operator', 'steady', 'dissipative', 'systems', 'lattice', 'protein', 'folding', 'annealing', 'interpretability', 'network', 'decoders', 'local', 'ergotropy', 'dynamically', 'witnesses', 'localized', 'phases', 'spectral', 'representational', 'similarity', 'limited', 'neurons', 'an', 'first', 'second', 'order', 'optimization', 'algorithms', 'monte', 'carlo', 'chiral', 'syk', 'three', 'holography', 'time', 'reversal', 'mirror', 'inside', 'granular', 'suspension', 'way', 'measuring', 'ultrasound', 'diffusion', 'coefficient', 'u', 'net', '3', 'anomalous', 'mixture', 'estimates', 'me', 'tracking', 'data', 'exact', 'superconducting', 'processor', 'global', 'population', 'crisis', 'scenario', 'predicted', 'most', 'general', 'dynamic', 'representation', 'energy', 'quenched', 'charged', 'parallel', 'spatial', 'photonic', 'ising', 'multiplexing', 'accelerating', 'combinatorial', 'zipping', 'scalable', 'approach', 'diagonal', 'efficient', 'backflow', 'ab', 'initio', 'chemistry', 'effects', 'galactic', 'irradiation', 'thermal', 'electronic', 'transport', 'tungsten', 'robust', 'prediction', 'frictional', 'contact', 'near', 'jamming', 'suspensions', 'employing', 'symmetries', 'living', 'symmetry', 'fibrations', 'synchronization', 'biological', 'applications', 'higher', 'contagion', 'processes', '1', '99', 'dimensions', 'slowly', 'varying', 'potentials', 'additional', '2d', 'bidisperse', 'packings', 'stabilization', 'fermi', 'liquid', 'behavior', 'interactions', 'metals', 'training', 're', 'crystal', 'elastomer', 'metamaterials', 'pluripotent', 'functionality', 'percolation', 'thresholds', 'connectivity', 'leveraging', 'recurrence', 'wavefunctions', 'scale', 'simulations', 'heisenberg', 'antiferromagnets', 'square', 'anderson', 'small', 'world', 'graphs', 'sampling', 'through', 'algorithmic', 'convex', 'perceptron', 'problems', 'scaling', 'transitions', 'fock', 'space', 'real', 'state', 'kinetic', 'reveals', 'task', 'dependent', 'flow', 'sparsely', 'active', 'nonequilibrium', 'identification', 'soft', 'amorphous', 'al', '2', 'o', 'via', 'principles', 'passive', 'leakage', 'removal', 'unit', 'transmon', 'array', 'versus', 'unidirectional', 'lattices', 'landscapes', 'from', 'typical', 'deviations', 'decoherence', 'self', 'dual', 'criticality', 'ma ...
# data for title 5: (tensor([46, 41, 47, 48, 37, 38, 49, 50, 51, 52]), tensor(1))
# category of article 5: physics.chem-ph
# index of this category: 1
# indexes to title:
# hierarchical
# quantum
# embedding
# by
# machine
# learning
# for
# large
# molecular
# assemblies

# %%
train_size = int(0.8 * len(dataset))
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, len(dataset) - train_size])
len(train_dataset), len(test_dataset)
# Out:
# (991931, 247983)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
for batch, (X,y) in enumerate(train_dataloader):
    if batch > 5:
        break
    print(X,y)
# Variable sizes problem
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 for batch, (X,y) in enumerate(train_dataloader):
#       2     if batch > 5:
#       3         break
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)    396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\_utils\collate.py:212, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\_utils\collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File c:\Users\cheri\nsi\M1\Arxiv-ML\env\Lib\site-packages\torch\utils\data\_utils\collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# RuntimeError: stack expects each tensor to be equal size, but got [9] at entry 0 and [10] at entry 1

# %%
# We fix it using a collate function that uses padding 
def custom_collate(batch, pad_value=0):
    sequences, labels = zip(*batch)
    padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=pad_value)
    labels = torch.tensor(labels)
    return padded_sequences, labels

train_dataloader = DataLoader(train_dataset, collate_fn=custom_collate, batch_size=5, shuffle=True)
test_dataloader = DataLoader(test_dataset, collate_fn=custom_collate, batch_size=5, shuffle=True)

# %%
for batch, (X,y) in enumerate(train_dataloader):
    if batch > 1:
        break
    print(X,y)
# Out:
# tensor([[    7,  3873,   771,     2,  5103,     6, 17438,  1852,  1514,     0,
#              0,     0],
#         [  244,  1780,  2003,    32,  6834,   450,     6,    19,   409,   659,
#           1201,   501],
#         [ 5577,  8152,  1863,     0,     0,     0,     0,     0,     0,     0,
#              0,     0],
#         [   18, 11008,  2556,   602,     0,  6972,     2, 14685,  2022,     0,
#              0,     0],
#         [  645,  2129,  2853,  2061,     6,  1827,   707,     0,     0,     0,
#              0,     0]]) tensor([ 46,  20, 121, 108,  84])
# tensor([[14250,   585,     2,    19,  1216,  3760,  6709,  7004,     0,    19,
#           5547,     0],
#         [    0,  2198,  6803,   383,  4102,  3417,  7097,  2269,   383,  3220,
#          14200,  7097],
#         [ 4776,  2040,   693,  9531,  2513,    32,  9529,     0,     0,     0,
#              0,     0],
#         [ 1841,  1881,   534,  2045, 16756,     6,   960,  6886,     7,  3009,
#           1080,     0],
#         [    0,  2618,  3275,     6,    26,   109,   110,    93,  7700,  1176,
#              0,     0]]) tensor([153,  71, 144,   3,   6])

# %%
# We can finally create the training loop

# Hyperparameters
vocab_size = len(dataset.wtoi)         # Taille du vocabulaire
embedding_dim = 10                     # Dimension des embeddings
hidden_dim = 256                       # Dimension des couches cachées
num_classes = len(dataset.ctoi)        # Nombre de classes de sortie
num_hidden_layers = 1                  # Nombre de couches cachées
num_epochs = 3                         # Nombre d'époques d'entraînement
learning_rate = 0.001                  # Taux d'apprentissage

# %%
# model setup 
model = MLPClassifier(vocab_size, embedding_dim, hidden_dim, num_classes, num_hidden_layers)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# MLPClassifier(
#   (embedding): Embedding(38963, 10)
#   (pool): AdaptiveAvgPool1d(output_size=1)
#   (input_layer): Linear(in_features=10, out_features=256, bias=True)
#   (hidden_layers): ModuleList()
#   (output_layer): Linear(in_features=256, out_features=172, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop 
for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0
    for batch_idx, (padded_sequences, labels) in enumerate(train_dataloader):
        padded_sequences = padded_sequences.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(padded_sequences)  # [batch_size, num_classes]
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
    avg_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_loss:.4f}")


    # Évaluation
    model.eval()
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for padded_sequences, labels in test_dataloader:
            padded_sequences = padded_sequences.to(device)
            labels = labels.to(device)
            outputs = model(padded_sequences)
            # Prédictions : indice de la classe avec la plus grande probabilité
            predictions = outputs.argmax(dim=1)
            total_correct += (predictions == labels).sum().item()
            total_samples += labels.size(0)
            
    accuracy = total_correct / total_samples * 100
    print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/3, Training Loss: 2.8570
# Test Accuracy: 40.03%
# Epoch 2/3, Training Loss: 2.2537
# Test Accuracy: 43.69%
# Epoch 3/3, Training Loss: 2.1363
# Test Accuracy: 44.73%
