# %% [markdown]
# # Notebook to use / test the extractions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('extractions/CSV/BySubCats/20250306_222102.csv')
df
# Out:
#                                       id  \
# 0      http://arxiv.org/abs/2503.03728v1
# 1      http://arxiv.org/abs/2503.03719v1
# 2      http://arxiv.org/abs/2503.03673v1
# 3      http://arxiv.org/abs/2503.03632v1
# 4      http://arxiv.org/abs/2503.03429v1
# ...                                  ...
# 21395  http://arxiv.org/abs/2112.11917v3
# 21396  http://arxiv.org/abs/2112.09044v3
# 21397  http://arxiv.org/abs/2112.08792v2
# 21398  http://arxiv.org/abs/2112.08568v4
# 21399  http://arxiv.org/abs/2112.08463v2
#
#                                                    title  \
# 0                  Variations on Hilbert--Burch matrices
# 1      Positivity of generalized cluster scattering d...
# 2                 F-theory with hyperelliptic fibrations
# 3           Rare Flat Bands for Periodic Graph Operators
# 4      On the classification of centralizers of ODOs:...
# ...                                                  ...
# 21395  Stability analysis of an eight parameter SIR-t...
# ...
